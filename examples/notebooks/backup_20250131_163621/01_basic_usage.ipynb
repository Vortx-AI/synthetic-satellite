# %% [markdown]
# # Basic Usage of Vortx AGI Memory System
#
# This notebook demonstrates the basic usage of the Vortx AGI Memory System for Earth observation data.
#
# ## Contents
# 1. Memory System Setup
# 2. Loading and Processing Cognitive Data
# 3. Creating Episodic Earth Memories
# 4. Memory Operations and Reasoning
# 5. Memory Visualization
#
# Author: Vortx Team
# License: MIT

# %%
# Import required libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

from vortx import AGIMemorySystem
from vortx.utils import setup_environment
from vortx.viz import CognitiveVisualizer
from vortx.memory import EpisodicMemory, SemanticMemory
